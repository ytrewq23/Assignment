# %% [markdown]
# <a href="https://colab.research.google.com/github/ytrewq23/Assignment/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(42)

n = 1000000

data = np.random.randint(
    100,
    5000000,
    size=(n, 5)
)

print( data.shape)
# Out:
# (1000000, 5)

# %%
print(data[:10])
# Out:
# [[1692843 4304672 4926584 2234589 1570106]
#  [1136174 4044987 1240011 4472571 2138342]
#  [4523769 4981605 1766991 4521473 3344869]
#  [ 791843  103455 1262852 1396125 1307471]
#  [ 917140 2253982 3530509 4849215 4721439]
#  [4842547 1501042 4260129 3275809   84754]
#  [1954454 2416282 3474775 2653091 2428488]
#  [ 528278 2663146 2586744 2570506 3416764]
#  [3385759 3385457 2795613 1465789   68248]
#  [1825765 2745783 3397823 3003858 4056618]]

# %%
print(data[-10:])
# Out:
# [[4583888  133044 2130794 4671611 4508960]
#  [4006420  398764 2551681 1239359 3282693]
#  [2719430 4130708 3683540 1849784 1821177]
#  [1190930 2856554  199659 2721270 1137000]
#  [3154230 2236129 4173335  122550 1585593]
#  [ 155791 3012335  942764 1342166 1084071]
#  [4933090 2370926 3073297 4915712 1322239]
#  [4836514 4218999 2450840 4099697 3059954]
#  [1974739 1070371 3812522 3016371 4736076]
#  [3110419 3164560 1627712 2113891 1644593]]

# %%
print(data[100000:100010])
# Out:
# [[1365110 4676400 1355767 3857217 2753218]
#  [1775784 2665088 4369461 4146432 1860998]
#  [3518908 1899965 2124233 4110414 1623056]
#  [2704133 1072770 3337653 4306165 2975917]
#  [ 797548 2996181 1130135 4663030  883385]
#  [1557656 2412878 3609458  384928  766448]
#  [  10248  656397 3681599 2762099 2477984]
#  [4889615 4119843 2886226 1750856 2561249]
#  [4922066 1194760 4955338 4833553 4469301]
#  [1408852 2479192 4257482  898215 4705013]]

# %%
purchase_data = data[:, 0:2]

print(purchase_data[:10])
# Out:
# [[1692843 4304672]
#  [1136174 4044987]
#  [4523769 4981605]
#  [ 791843  103455]
#  [ 917140 2253982]
#  [4842547 1501042]
#  [1954454 2416282]
#  [ 528278 2663146]
#  [3385759 3385457]
#  [1825765 2745783]]

# %%
print(np.min(data[:,0]))
print(np.max(data[:,0]))
# Out:
# 101
# 4999998

# %%
mean_purchase = np.mean(data[:, 0])

print("Орташа сомасы:", mean_purchase)
# Out:
# Орташа сомасы: 2500994.456709

# %%
first = data[:1000]

print(first)
# Out:
# [[1692843 4304672 4926584 2234589 1570106]
#  [1136174 4044987 1240011 4472571 2138342]
#  [4523769 4981605 1766991 4521473 3344869]
#  ...
#  [3132393 1541137 4032471 4854601 2602452]
#  [1531917 2015174 4720158 3963031 4540434]
#  [1802602 1462638 2026919 2074620 2432765]]

# %%
every = data[::10]

print(every)
# Out:
# [[1692843 4304672 4926584 2234589 1570106]
#  [2670095 4450912 4997995 4798769 1871028]
#  [2726028 3853439 1843500 1079211  996207]
#  ...
#  [3577945 1301204  539542 4841549 3671536]
#  [2310003  107114 3103936 3832460 2935597]
#  [4583888  133044 2130794 4671611 4508960]]

# %%
last = data[-5000:]

print(last)
# Out:
# [[2713107 2277878 1997600 4381458 1840048]
#  [3607999  733280   71031 1655970 3980877]
#  [1665512 2553813  482446 1569544 3932665]
#  ...
#  [4836514 4218999 2450840 4099697 3059954]
#  [1974739 1070371 3812522 3016371 4736076]
#  [3110419 3164560 1627712 2113891 1644593]]

# %%
columns = data[:, 1:5]

print(columns)
# Out:
# [[4304672 4926584 2234589 1570106]
#  [4044987 1240011 4472571 2138342]
#  [4981605 1766991 4521473 3344869]
#  ...
#  [4218999 2450840 4099697 3059954]
#  [1070371 3812522 3016371 4736076]
#  [3164560 1627712 2113891 1644593]]

# %%
only = data[:, [0, 1, 2]]

print(only[:10])
# Out:
# [[1692843 4304672 4926584]
#  [1136174 4044987 1240011]
#  [4523769 4981605 1766991]
#  [ 791843  103455 1262852]
#  [ 917140 2253982 3530509]
#  [4842547 1501042 4260129]
#  [1954454 2416282 3474775]
#  [ 528278 2663146 2586744]
#  [3385759 3385457 2795613]
#  [1825765 2745783 3397823]]

# %%
separate_data = data[100000:200001]
print(separate_data)
# Out:
# [[1365110 4676400 1355767 3857217 2753218]
#  [1775784 2665088 4369461 4146432 1860998]
#  [3518908 1899965 2124233 4110414 1623056]
#  ...
#  [4718898 1237772 1047059 3772368 3462540]
#  [2740721   82135 3443844 2470205 1402979]
#  [1268899 3963657 4314014   68286 3692809]]

# %%
import numpy as np
# Сатып алу сомалары
data = np.array([
    5000, 7000, 8000, 6000, 9000,
    7500, 8500, 6500, 10000, 500000
])
# Орташа мән
mean = np.mean(data)
# Стандартты ауытқу
std = np.std(data)
# Z-score есептеу
z_scores = (data - mean) / std
# Аномалияларды анықтау
anomalies = data[np.abs(z_scores) > 2]
print("Орташа мән:", mean)
print("Z-score:", z_scores)
print("Аномалиялар:", anomalies)
# Out:
# Орташа мән: 56750.0
# Z-score: [-0.35023816 -0.33670239 -0.3299345  -0.34347028 -0.32316662 -0.33331845
#  -0.32655056 -0.34008633 -0.31639873  2.99986602]
# Аномалиялар: [500000]
